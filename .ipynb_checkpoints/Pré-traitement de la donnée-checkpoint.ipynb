# %%
from bs4 import BeautifulSoup
import requests
import random
import time
import json
import pandas as pd
import numpy as np

# %%
from secrets import ACCESS_DB, RIOT_API_KEY

# %% [markdown]
# ### Collecting user's name
# L'objectif est de récupérer 500'000 utilisateurs pour analyser leurs 20 dernières parties, soit 10'000'000 de lignes. Les technologies principales utilisées sont :
# - Python avec ses librairies de scraping (BeautifulSoup, Selenium) et de traitement de la donnée (pandas, numpy, ...)
# - MySQL pour le stockage faible des données (< 10'000)
# - PostgreSQL pour le stockage massif des données (> 5'000'000)

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By

# %%
path = "C:\Program Files (x86)\EdgeDriver\msedgedriver.exe"
service = Service(path, verbose = True)

options = Options()
options.add_argument('inprivate')
options.add_argument('headless')

# %%
def openLink(url):
    driver = webdriver.Edge(service=service, options=options)
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    driver.close()
    
    return soup

def summonersName(url):
    soup = openLink(url)

    return [summoner['id'] for summoner in soup.findAll('tr', {"class":"css-1kk0pwf e1g3wlsd9"})]

# %%
page = 500

summonersNameList = []
for i in range(4501):
    summonersNameList += summonersName(f"https://euw.op.gg/leaderboards/tier?region=euw&page={page + i}")
    time.sleep(random.uniform(0, 1.25))

# Sauvegarder les données utilisateurs
with open("summonersNameList.txt", "w") as file:
    json.dump(summonersNameList, file)

# %% [markdown]
# Il faut en moyenne 5 secondes par page pour récupérer les noms utilisateurs

# %%
with open('summonersNameList.txt') as json_file:
    data = json.load(json_file)

# %%
data = list(set(data))

# %% [markdown]
# ### Collecting user informations

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.134 Safari/537.36 Edg/103.0.1264.77",
    "Accept-Language": "fr,fr-FR;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": RIOT_API_KEY
}

# %%
def summonerDetails(url):
    response = requests.get(url, headers=header)
    
    return response.json()

# %%
summonerName = "Yoshigaï"
summoner = f"https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summonerName}"

# %%
summonerDetails(summoner)

# %% [markdown]
# ### Collecting the last 20 games

# %%
puuid = "OOLWF-QQsUv2WmdnK3KNSA_J-RFuN4Ai9D9LFjpp98_UEgpxQyBUbD_z_SXaZTYp1iYZ9007UowQ1A"
matchsUrl = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20"

# %%
summonerDetails(matchsUrl)

# %% [markdown]
# ### Collecting the details of a game

# %%
match = "EUW1_5999047056"
matchDetailsUrl = f"https://europe.api.riotgames.com/lol/match/v5/matches/{match}"

# %%
matchDetails = summonerDetails(matchDetailsUrl)
matchDetails

# %%
matchDetails['info']['teams']

# %%
dictParticipants = matchDetails['info']['participants']

# for participant in dictParticipants:
#     del participant['challenges']
    
dictParticipants[0]

# %% [markdown]
# ### Tables
# - matchs : matchDetails['info']
# - participants :
#     - matchDetails['info']['participants']
#     - matchDetails['info']['teams']
#     - dictParticipants[0]['perks']['styles'])

# %% [markdown]
# ## PRE-PROCESSING
# ### Matchs Table

# %%
dictInfos = matchDetails['info'].copy()

# %%
entriesToRemove = ["teams", "participants"]

for entry in entriesToRemove:
    del dictInfos[entry]
    
dictInfos

# %%
dfInfos = pd.DataFrame([dictInfos])
dfInfos

# %% [markdown]
# ### Participants Table
# #### List of champion's bans

# %%
bansList = [element['championId'] for bans in matchDetails['info']['teams'] for element in bans['bans']]
bansList

# %% [markdown]
# #### List of champion's runes

# %%
perkList = [element for participantDetails in dictParticipants for element in [element['perk'] for styles in participantDetails['perks']['styles'] for element in styles['selections']]]
perkList

# %%
from itertools import zip_longest

def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

# %%
dictPerks = list(grouper(perkList, 6, 'x'))
dictPerks

# %%
participantRunes = {}
for i in range(len(dictPerks[0])):
    participantRunes[f'perk{i}'] = []
    for j in dictPerks:
        participantRunes[f'perk{i}'] += [j[i]]

participantRunes

# %%
dfParticipantRunes = pd.DataFrame(participantRunes)
dfParticipantRunes

# %%
dfParticipants = pd.DataFrame(dictParticipants)
dfParticipants.head()

# %% [markdown]
# #### Concatenation of columns

# %%
dfParticipants['bans'] = bansList
dfParticipants = pd.concat([dfParticipants, dfParticipantRunes], axis=1, join='outer')

# %%
dfParticipants.head()

# %% [markdown]
# ## Process automation

# %%
from bs4 import BeautifulSoup
import requests
import random
import time
import json
import pandas as pd
import numpy as np
from itertools import zip_longest
from tqdm import tqdm

# %%
with open('summonersNameList.txt') as json_file:
    data = json.load(json_file)

# %%
data = list(set(data))
len(data)
# Out:
# 447687

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.134 Safari/537.36 Edg/103.0.1264.77",
    "Accept-Language": "fr,fr-FR;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": RIOT_API_KEY
}

# %%
def summonerDetails(url):
    response = requests.get(url, headers=header)
    
    return response.json()

def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def informationsTable(matchDetails):
    entriesToKeep = ['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameStartTimestamp', 'gameVersion']
    matchDetailsInfo = {entry: matchDetails[entry] for entry in entriesToKeep}

    return pd.DataFrame([matchDetailsInfo])

def participantsTable(matchDetails):
    bansList = [element['championId'] for bans in matchDetails['teams'] for element in bans['bans']]
    dictParticipants = matchDetails['participants']
    perkList = [element for participantDetails in dictParticipants for element in [element['perk'] for styles in participantDetails['perks']['styles'] for element in styles['selections']]]
    dictPerks = list(grouper(perkList, 6, 'x'))

    participantRunes = {}
    for i in range(len(dictPerks[0])):
        participantRunes[f'perk{i}'] = []
        for j in dictPerks:
            participantRunes[f'perk{i}'] += [j[i]]

    dfParticipants = pd.DataFrame(dictParticipants)
    dfParticipants['bans'] = bansList
    dfParticipantRunes = pd.DataFrame(participantRunes)
    
    removeColumns = ['challenges', 'perks']
    for col in removeColumns:
        del dfParticipants[col]

    return pd.concat([dfParticipants, dfParticipantRunes], axis=1, join='outer')

# %% [markdown]
# ## CREATING MYSQL TABLES

# %%
dtypesList = list(set(dfParticipants.dtypes))
dtypesList
# Out:
# [dtype('int64'), dtype('O'), dtype('bool')]

# %%
listColumns = []

for i in list(dfParticipants.dtypes.items()):
    if i[1] == dtypesList[0]: # np.object
        listColumns.append(f"{i[0]} VARCHAR(200),")
        
    elif i[1] == dtypesList[1]: # np.int64
        listColumns.append(f"{i[0]} INT,")
        
    else:
        listColumns.append(f"{i[0]} BOOLEAN,")

# %%
# for el in listColumns:
#     print(el)

# %%
import pymysql
from sqlalchemy import create_engine

# %%
# Connection à l'instance de la database
def connect_to_instance_db():
    try:
        conn = pymysql.connect(
                host='localhost',
                user='root',
                password=ACCESS_DB,
                charset='utf8mb4')
    except pymysql.err.OperationalError as e:
        raise e
    else:
        print("Connection Successful!")
    return conn

# Création de la database
def create_db(connection, cursor):    
    queries = (
    "DROP DATABASE IF EXISTS lol_stats",
    "CREATE DATABASE lol_stats",
    "USE lol_stats"
    )
    
    for query in queries:
        cursor.execute(query)
        connection.commit()
        
    print("The database has been successfully created")

# Création des tables
def create_table():
    connection = connect_to_instance_db()
    cursor = connection.cursor()
    
    create_db(connection, cursor)
    
    queries = (
    "DROP TABLE IF EXISTS match_informations",
    '''CREATE TABLE match_informations(
       gameId BIGINT,
       gameCreation BIGINT,
       gameDuration INT,
       gameEndTimestamp BIGINT,
       gameStartTimestamp BIGINT,
       gameVersion CHAR(20),
       PRIMARY KEY(gameId))''',

    "DROP TABLE IF EXISTS participants",
    '''CREATE TABLE participants(
       id INT NOT NULL AUTO_INCREMENT,
       assists INT,
       baronKills INT,
       basicPings INT,
       bountyLevel INT,
       champExperience INT,
       champLevel INT,
       championId INT,
       championName VARCHAR(200),
       championTransform INT,
       consumablesPurchased INT,
       damageDealtToBuildings INT,
       damageDealtToObjectives INT,
       damageDealtToTurrets INT,
       damageSelfMitigated INT,
       deaths INT,
       detectorWardsPlaced INT,
       doubleKills INT,
       dragonKills INT,
       eligibleForProgression BOOLEAN,
       firstBloodAssist BOOLEAN,
       firstBloodKill BOOLEAN,
       firstTowerAssist BOOLEAN,
       firstTowerKill BOOLEAN,
       gameEndedInEarlySurrender BOOLEAN,
       gameEndedInSurrender BOOLEAN,
       goldEarned INT,
       goldSpent INT,
       individualPosition VARCHAR(200),
       inhibitorKills INT,
       inhibitorTakedowns INT,
       inhibitorsLost INT,
       item0 INT,
       item1 INT,
       item2 INT,
       item3 INT,
       item4 INT,
       item5 INT,
       item6 INT,
       itemsPurchased INT,
       killingSprees INT,
       kills INT,
       lane VARCHAR(200),
       largestCriticalStrike INT,
       largestKillingSpree INT,
       largestMultiKill INT,
       longestTimeSpentLiving INT,
       magicDamageDealt INT,
       magicDamageDealtToChampions INT,
       magicDamageTaken INT,
       neutralMinionsKilled INT,
       nexusKills INT,
       nexusLost INT,
       nexusTakedowns INT,
       objectivesStolen INT,
       objectivesStolenAssists INT,
       participantId INT,
       pentaKills INT,
       physicalDamageDealt INT,
       physicalDamageDealtToChampions INT,
       physicalDamageTaken INT,
       profileIcon INT,
       puuid VARCHAR(200),
       quadraKills INT,
       riotIdName VARCHAR(200),
       riotIdTagline VARCHAR(200),
       role VARCHAR(200),
       sightWardsBoughtInGame INT,
       spell1Casts INT,
       spell2Casts INT,
       spell3Casts INT,
       spell4Casts INT,
       summoner1Casts INT,
       summoner1Id INT,
       summoner2Casts INT,
       summoner2Id INT,
       summonerLevel INT,
       summonerId VARCHAR(200),
       summonerName VARCHAR(200),
       teamEarlySurrendered BOOLEAN,
       teamId INT,
       teamPosition VARCHAR(200),
       timeCCingOthers INT,
       timePlayed INT,
       totalDamageDealt INT,
       totalDamageDealtToChampions INT,
       totalDamageShieldedOnTeammates INT,
       totalDamageTaken INT,
       totalHeal INT,
       totalHealsOnTeammates INT,
       totalMinionsKilled INT,
       totalTimeCCDealt INT,
       totalTimeSpentDead INT,
       totalUnitsHealed INT,
       tripleKills INT,
       trueDamageDealt INT,
       trueDamageDealtToChampions INT,
       trueDamageTaken INT,
       turretKills INT,
       turretTakedowns INT,
       turretsLost INT,
       unrealKills INT,
       visionScore INT,
       visionWardsBoughtInGame INT,
       wardsKilled INT,
       wardsPlaced INT,
       win BOOLEAN,
       bans INT,
       perk0 INT,
       perk1 INT,
       perk2 INT,
       perk3 INT,
       perk4 INT,
       perk5 INT,
       gameId BIGINT,
       PRIMARY KEY(id),
       FOREIGN KEY(gameId) REFERENCES match_informations(gameId))'''
    )
    
    for query in queries:
        cursor.execute(query)
        connection.commit()
        
    print("The tables have been successfully created")

# %%
create_table()
# Out:
# Connection Successful!
# The database has been successfully created
# The tables have been successfully created

# %% [markdown]
# ## INSERTING DATA IN MYSQL TABLES

# %%
sqlEngine = create_engine(f'mysql+pymysql://root:{ACCESS_DB}@localhost/lol_stats')
dbConnection = sqlEngine.connect()

# %%
for summonerName in data:
    puuid = summonerDetails(f"https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summonerName}")['puuid']
    matches = summonerDetails(f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20")
    
    for match in tqdm(matches):
        matchDetails = summonerDetails(f"https://europe.api.riotgames.com/lol/match/v5/matches/{match}")['info']
        
        # Table Informations
        dfInfos = informationsTable(matchDetails)
        dfInfos.to_sql('match_informations', dbConnection, if_exists="append", index=False)
        
        # Table Participants
        dfParticipants = participantsTable(matchDetails)
        dfParticipants['gameId'] = np.int(dfInfos['gameId'])
        dfParticipants.to_sql('participants', dbConnection, if_exists="append", index=False)
        
    break
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:10<00:00,  1.83it/s]

# %%
matchDetails
# Out:
# {'gameCreation': 1650142762000,
#  'gameDuration': 1925,
#  'gameEndTimestamp': 1650144716743,
#  'gameId': 5827989934,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-5827989934',
#  'gameStartTimestamp': 1650142791699,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '12.7.433.4138',
#  'mapId': 11,
#  'participants': [{'assists': 5,
#    'baronKills': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 220,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.08377387845170604,
#     'controlWardsPlaced': 1,
#     'damagePerMinute': 465.4422969778435,
#     'damageTakenOnTeamPercentage': 0.23029784374708942,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0.0811612606048584,
#     'effectiveHealAndShielding': 5259.4521484375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 2,
#     'enemyJungleMonsterKills': 8,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 371.34974403504157,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 1,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 1.1428571428571428,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.23529411764705882,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 2,
#     'laneMinionsFirst10Minutes': 75,
#     'laningPhaseGoldExpAdvantage': -0.03942310810089111,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 43,
#     'maxKillDeficit': 1,
#     'maxLevelLeadLaneOpponent': 2,
#     'moreEnemyJungleThanOpponent': -142.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6632,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 4,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 20,
#     'skillshotsHit': 16,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 8,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 8,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 5,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.16294758106702906,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 2,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 5,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.9657856822013855,
#     'visionScorePerMinute': 0.5476779648085378,
#     'wardTakedowns': 1,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 0},
#    'champExperience': 17018,
#    'champLevel': 17,
#    'championId': 114,
#    'championName': 'Fiora',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 7823,
#    'damageDealtToObjectives': 7823,
#    'damageDealtToTurrets': 7823,
#    'damageSelfMitigated': 20251,
#    'deaths': 7,
#    'detectorWardsPlaced': 1,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': True,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 11915,
#    'goldSpent': 9825,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 1055,
#    'item1': 3074,
#    'item2': 1029,
#    'item3': 6632,
#    'item4': 3047,
#    'item5': 3133,
#    'item6': 3340,
#    'itemsPurchased': 20,
#    'killingSprees': 1,
#    'kills': 3,
#    'lane': 'TOP',
#    'largestCriticalStrike': 549,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 393,
#    'magicDamageDealt': 511,
#    'magicDamageDealtToChampions': 511,
#    'magicDamageTaken': 8566,
#    'neutralMinionsKilled': 8,
#    'nexusKills': 1,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 305, 'var2': 0, 'var3': 0},
#        {'perk': 8009, 'var1': 1405, 'var2': 0, 'var3': 0},
#        {'perk': 9103, 'var1': 29, 'var2': 10, 'var3': 0},
#        {'perk': 8014, 'var1': 181, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8473, 'var1': 654, 'var2': 0, 'var3': 0},
#        {'perk': 8453, 'var1': 1654, 'var2': 29, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 130062,
#    'physicalDamageDealtToChampions': 8652,
#    'physicalDamageTaken': 16857,
#    'profileIcon': 3006,
#    'puuid': 'cw6jYwcOt08zz6X-6fIL-oRw1Ix38TXmnNmeaMYODFD3mCN8ec07lrdnnCk23il-Y3HTzOdD9pDzQQ',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 146,
#    'spell2Casts': 11,
#    'spell3Casts': 54,
#    'spell4Casts': 9,
#    'summoner1Casts': 5,
#    'summoner1Id': 14,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'QhykeK8tmeE_yVndS4_wqEtgMeYvP_z77atVaeFUnBOoUq8',
#    'summonerLevel': 65,
#    'summonerName': 'rebeccaplays',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 6,
#    'timePlayed': 1925,
#    'totalDamageDealt': 136564,
#    'totalDamageDealtToChampions': 14934,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 26742,
#    'totalHeal': 10686,
#    'totalHealsOnTeammates': 5259,
#    'totalMinionsKilled': 227,
#    'totalTimeCCDealt': 83,
#    'totalTimeSpentDead': 249,
#    'totalUnitsHealed': 12,
#    'tripleKills': 0,
#    'trueDamageDealt': 5990,
#    'trueDamageDealtToChampions': 5770,
#    'trueDamageTaken': 1318,
#    'turretKills': 2,
#    'turretTakedowns': 4,
#    'turretsLost': 3,
#    'unrealKills': 0,
#    'visionScore': 17,
#    'visionWardsBoughtInGame': 1,
#    'wardsKilled': 1,
#    'wardsPlaced': 9,
#    'win': True},
#   {'assists': 8,
#    'baronKills': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 311,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 112.60000029206276,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 600,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 665.4158464198478,
#     'damageTakenOnTeamPercentage': 0.2757717940615425,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 5,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestDragonTakedown': 801.7638508791171,
#     'earlyLaningPhaseGoldExpAdvantage': -0.2845895290374756,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 7,
#     'enemyJungleMonsterKills': 8.000000029802322,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 2,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'goldPerMinute': 490.33840553906424,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'highestCrowdControlScore': 1,
#     'immobilizeAndKillWithAlly': 6,
#     'initialBuffCount': 2,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 60.00000008940697,
#     'junglerKillsEarlyJungle': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3.4,
#     'killAfterHiddenWithAlly': 2,
#     'killParticipation': 0.5,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 2,
#     'killsOnLanersEarlyJungleAsJungler': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 6,
#     'laningPhaseGoldExpAdvantage': -0.15114259719848633,
#     'legendaryCount': 1,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 4,
#     'maxKillDeficit': 1,
#     'maxLevelLeadLaneOpponent': 1,
#     'moreEnemyJungleThanOpponent': -82,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6653,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 13,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 2,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 4,
#     'shortestTimeToAceFromFirstTakedown': 46.40161609587699,
#     'skillshotsDodged': 18,
#     'skillshotsHit': 22,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 0,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 17,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 10,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.23295670222026554,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 2,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 2,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 5,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.46635645627975464,
#     'visionScorePerMinute': 0.4695651219915377,
#     'wardTakedowns': 4,
#     'wardTakedownsBefore20M': 2,
#     'wardsGuarded': 0},
#    'champExperience': 18226,
#    'champLevel': 17,
#    'championId': 876,
#    'championName': 'Lillia',
#    'championTransform': 0,
#    'consumablesPurchased': 0,
#    'damageDealtToBuildings': 984,
#    'damageDealtToObjectives': 38915,
#    'damageDealtToTurrets': 984,
#    'damageSelfMitigated': 13616,
#    'deaths': 5,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 2,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 15733,
#    'goldSpent': 15700,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3157,
#    'item1': 3020,
#    'item2': 4637,
#    'item3': 3135,
#    'item4': 3165,
#    'item5': 6653,
#    'item6': 3364,
#    'itemsPurchased': 19,
#    'killingSprees': 1,
#    'kills': 9,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 734,
#    'magicDamageDealt': 176949,
#    'magicDamageDealtToChampions': 17144,
#    'magicDamageTaken': 11800,
#    'neutralMinionsKilled': 167,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8128, 'var1': 1352, 'var2': 15, 'var3': 0},
#        {'perk': 8126, 'var1': 783, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 400, 'var2': 5, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8234, 'var1': 17112, 'var2': 0, 'var3': 0},
#        {'perk': 8232, 'var1': 5, 'var2': 20, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 12592,
#    'physicalDamageDealtToChampions': 446,
#    'physicalDamageTaken': 19060,
#    'profileIcon': 907,
#    'puuid': 't9Wo3SPoivHvECCj86O-lnA1ZcFgVoRc_RDxelqyDvgMhtgv1eG4ViVtxUXBM7zgKVKJTTbXQJsQNw',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 152,
#    'spell2Casts': 73,
#    'spell3Casts': 80,
#    'spell4Casts': 6,
#    'summoner1Casts': 16,
#    'summoner1Id': 11,
#    'summoner2Casts': 5,
#    'summoner2Id': 4,
#    'summonerId': '02wZ47szDitt4330CEvfl8hEIkfXwtag5FjqCep4fKN4KsA',
#    'summonerLevel': 541,
#    'summonerName': 'Käptη Iglo',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 16,
#    'timePlayed': 1925,
#    'totalDamageDealt': 250805,
#    'totalDamageDealtToChampions': 21350,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 32023,
#    'totalHeal': 16134,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 73,
#    'totalTimeCCDealt': 390,
#    'totalTimeSpentDead': 207,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 61264,
#    'trueDamageDealtToChampions': 3759,
#    'trueDamageTaken': 1162,
#    'turretKills': 1,
#    'turretTakedowns': 1,
#    'turretsLost': 3,
#    'unrealKills': 0,
#    'visionScore': 15,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 4,
#    'wardsPlaced': 0,
#    'win': True},
#   {'assists': 15,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 267,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 4,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 300,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.19527639936820304,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 645.9317262941236,
#     'damageTakenOnTeamPercentage': 0.20683391665841455,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestDragonTakedown': 1445.9271840692604,
#     'earlyLaningPhaseGoldExpAdvantage': -0.11408168077468872,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 23,
#     'enemyJungleMonsterKills': 4,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 455.64301840481806,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 10,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3,
#     'killAfterHiddenWithAlly': 2,
#     'killParticipation': 0.6176470588235294,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 2,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 7,
#     'laneMinionsFirst10Minutes': 68,
#     'laningPhaseGoldExpAdvantage': 0.1866922378540039,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 30,
#     'maxKillDeficit': 1,
#     'maxLevelLeadLaneOpponent': 2,
#     'moreEnemyJungleThanOpponent': -142.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6655,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 14,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 1,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 35,
#     'skillshotsHit': 34,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 2,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 9,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 21,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 13,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.22613546946097185,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 2,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 3,
#     'turretTakedowns': 3,
#     'turretsTakenWithRiftHerald': 5,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.6452167630195618,
#     'visionScorePerMinute': 0.5706112002727814,
#     'wardTakedowns': 0,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 18173,
#    'champLevel': 17,
#    'championId': 127,
#    'championName': 'Lissandra',
#    'championTransform': 0,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 2520,
#    'damageDealtToObjectives': 3374,
#    'damageDealtToTurrets': 2520,
#    'damageSelfMitigated': 10833,
#    'deaths': 7,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 14619,
#    'goldSpent': 12890,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 6655,
#    'item1': 4645,
#    'item2': 4629,
#    'item3': 1082,
#    'item4': 1058,
#    'item5': 3009,
#    'item6': 3340,
#    'itemsPurchased': 22,
#    'killingSprees': 2,
#    'kills': 6,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 582,
#    'magicDamageDealt': 156956,
#    'magicDamageDealtToChampions': 18569,
#    'magicDamageTaken': 6531,
#    'neutralMinionsKilled': 8,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8112, 'var1': 1255, 'var2': 0, 'var3': 0},
#        {'perk': 8126, 'var1': 630, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 400, 'var2': 5, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8009, 'var1': 3052, 'var2': 0, 'var3': 0},
#        {'perk': 8014, 'var1': 287, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 11071,
#    'physicalDamageDealtToChampions': 635,
#    'physicalDamageTaken': 16904,
#    'profileIcon': 4763,
#    'puuid': '6LVlYcI7V1qzJey0A8e0NRBBcsKsZaRx-x44BGR5T5B790ZH4upv5_J5WkqBAkbSLpWkoxdnsKZiTw',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 109,
#    'spell2Casts': 49,
#    'spell3Casts': 93,
#    'spell4Casts': 16,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 7,
#    'summoner2Id': 14,
#    'summonerId': 'PS0pJgKQbrcjO4yRx6yiX4SeupNfS1EKLhBXPvEdqN7vWiI',
#    'summonerLevel': 208,
#    'summonerName': 'ryolei',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 32,
#    'timePlayed': 1925,
#    'totalDamageDealt': 169549,
#    'totalDamageDealtToChampions': 20725,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 24017,
#    'totalHeal': 2922,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 217,
#    'totalTimeCCDealt': 266,
#    'totalTimeSpentDead': 283,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 1521,
#    'trueDamageDealtToChampions': 1521,
#    'trueDamageTaken': 582,
#    'turretKills': 1,
#    'turretTakedowns': 3,
#    'turretsLost': 3,
#    'unrealKills': 0,
#    'visionScore': 18,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 0,
#    'wardsPlaced': 11,
#    'win': True},
#   {'assists': 3,
#    'baronKills': 0,
#    'bountyLevel': 5,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 182,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 19.400000005960464,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 675,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 871.1779916615831,
#     'damageTakenOnTeamPercentage': 0.17962130228769815,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 6,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': -0.06157517433166504,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 11,
#     'enemyJungleMonsterKills': 4,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 576.2453636369577,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'highestChampionDamage': 1,
#     'immobilizeAndKillWithAlly': 4,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.5294117647058824,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 5,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 4,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 67,
#     'laningPhaseGoldExpAdvantage': -0.09738713502883911,
#     'legendaryCount': 1,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 45.400000005960464,
#     'maxKillDeficit': 1,
#     'maxLevelLeadLaneOpponent': 2,
#     'moreEnemyJungleThanOpponent': -142.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 6,
#     'multikillsAfterAggressiveFlash': 1,
#     'mythicItemUsed': 6673,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 3,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 12,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 1,
#     'skillshotsDodged': 23,
#     'skillshotsHit': 17,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 5,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 18,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 9,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.30499236391239476,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 2,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 2,
#     'turretTakedowns': 5,
#     'turretsTakenWithRiftHerald': 5,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 1.138222336769104,
#     'visionScorePerMinute': 0.5680872633514209,
#     'wardTakedowns': 2,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 16467,
#    'champLevel': 16,
#    'championId': 67,
#    'championName': 'Vayne',
#    'championTransform': 0,
#    'consumablesPurchased': 1,
#    'damageDealtToBuildings': 7666,
#    'damageDealtToObjectives': 11156,
#    'damageDealtToTurrets': 7666,
#    'damageSelfMitigated': 15056,
#    'deaths': 6,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 4,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 18489,
#    'goldSpent': 15510,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3046,
#    'item1': 3124,
#    'item2': 1053,
#    'item3': 3006,
#    'item4': 3091,
#    'item5': 6673,
#    'item6': 3363,
#    'itemsPurchased': 24,
#    'killingSprees': 3,
#    'kills': 15,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 275,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 3,
#    'longestTimeSpentLiving': 400,
#    'magicDamageDealt': 11270,
#    'magicDamageDealtToChampions': 2050,
#    'magicDamageTaken': 6602,
#    'neutralMinionsKilled': 32,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 4,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8008, 'var1': 55, 'var2': 7, 'var3': 0},
#        {'perk': 9101, 'var1': 4814, 'var2': 4791, 'var3': 0},
#        {'perk': 9104, 'var1': 17, 'var2': 20, 'var3': 0},
#        {'perk': 8014, 'var1': 629, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8139, 'var1': 707, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 400, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 153557,
#    'physicalDamageDealtToChampions': 16163,
#    'physicalDamageTaken': 11745,
#    'profileIcon': 1114,
#    'puuid': 'KCCkdp_uSfdDCAS_J5FFb4YIfmTjBhNGWe5v_jImjYCarUt1DgOSjwRYNllCH_NgdyhFwtryZDfa1Q',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 161,
#    'spell2Casts': 0,
#    'spell3Casts': 12,
#    'spell4Casts': 9,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 6,
#    'summoner2Id': 6,
#    'summonerId': 'In-1TGVgW9dn1XOIe2I1V2bxaAnaCZGJie2w4oMZ3oORgCcFWG23Xsn6ew',
#    'summonerLevel': 37,
#    'summonerName': 'Dewarang',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 13,
#    'timePlayed': 1925,
#    'totalDamageDealt': 198924,
#    'totalDamageDealtToChampions': 27952,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 20857,
#    'totalHeal': 1081,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 233,
#    'totalTimeCCDealt': 197,
#    'totalTimeSpentDead': 199,
#    'totalUnitsHealed': 1,
#    'tripleKills': 2,
#    'trueDamageDealt': 34096,
#    'trueDamageDealtToChampions': 9738,
#    'trueDamageTaken': 2509,
#    'turretKills': 4,
#    'turretTakedowns': 5,
#    'turretsLost': 3,
#    'unrealKills': 0,
#    'visionScore': 18,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 2,
#    'wardsPlaced': 11,
#    'win': True},
#   {'assists': 17,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 1,
#     'abilityUses': 144,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 1,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.22609590828031448,
#     'controlWardsPlaced': 12,
#     'damagePerMinute': 208.4249364407725,
#     'damageTakenOnTeamPercentage': 0.10747514324525534,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 6,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestDragonTakedown': 801.7638508791171,
#     'earlyLaningPhaseGoldExpAdvantage': 0.036757588386535645,
#     'effectiveHealAndShielding': 1370.705078125,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 42,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 318.233922791932,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 12,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3.5,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.6176470588235294,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 2,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 6,
#     'landSkillShotsEarlyGame': 3,
#     'laneMinionsFirst10Minutes': 5,
#     'laningPhaseGoldExpAdvantage': -0.09803766012191772,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 3,
#     'maxKillDeficit': 1,
#     'maxLevelLeadLaneOpponent': 1,
#     'moreEnemyJungleThanOpponent': -142.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 4005,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 15,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 46.40161609587699,
#     'skillshotsDodged': 24,
#     'skillshotsHit': 14,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 34,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 21,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 10,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.07296788333933878,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 2,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 5,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 1.4038358926773071,
#     'visionScorePerMinute': 2.6200565998117025,
#     'wardTakedowns': 10,
#     'wardTakedownsBefore20M': 4,
#     'wardsGuarded': 0},
#    'champExperience': 13971,
#    'champLevel': 15,
#    'championId': 888,
#    'championName': 'Renata',
#    'championTransform': 0,
#    'consumablesPurchased': 16,
#    'damageDealtToBuildings': 1499,
#    'damageDealtToObjectives': 3286,
#    'damageDealtToTurrets': 1499,
#    'damageSelfMitigated': 7406,
#    'deaths': 6,
#    'detectorWardsPlaced': 12,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 10210,
#    'goldSpent': 9600,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 4005,
#    'item1': 3158,
#    'item2': 3853,
#    'item3': 3504,
#    'item4': 6616,
#    'item5': 2055,
#    'item6': 3364,
#    'itemsPurchased': 32,
#    'killingSprees': 1,
#    'kills': 4,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 650,
#    'magicDamageDealt': 15829,
#    'magicDamageDealtToChampions': 5411,
#    'magicDamageTaken': 5032,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8112, 'var1': 870, 'var2': 0, 'var3': 0},
#        {'perk': 8126, 'var1': 411, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 400, 'var2': 5, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8226, 'var1': 250, 'var2': 145, 'var3': 0},
#        {'perk': 8210, 'var1': 39, 'var2': 0, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 5892,
#    'physicalDamageDealtToChampions': 890,
#    'physicalDamageTaken': 6733,
#    'profileIcon': 4794,
#    'puuid': 'XFrVZYgxjuXSneHQcs1Yt6o_vNdRc3mvXifjL0ataASsh_xUnJYG5v8g2fVBiRAtopQkrwPsmmQKQA',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 48,
#    'spell2Casts': 38,
#    'spell3Casts': 51,
#    'spell4Casts': 7,
#    'summoner1Casts': 5,
#    'summoner1Id': 4,
#    'summoner2Casts': 6,
#    'summoner2Id': 3,
#    'summonerId': 'q-qatb5Ic4JK1OioQK4mE3xOZH_pf2fOaSu-odsTimM0iZk',
#    'summonerLevel': 376,
#    'summonerName': 'ArcanV',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 21,
#    'timePlayed': 1925,
#    'totalDamageDealt': 22107,
#    'totalDamageDealtToChampions': 6687,
#    'totalDamageShieldedOnTeammates': 1370,
#    'totalDamageTaken': 12480,
#    'totalHeal': 522,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 20,
#    'totalTimeCCDealt': 196,
#    'totalTimeSpentDead': 132,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 385,
#    'trueDamageDealtToChampions': 385,
#    'trueDamageTaken': 713,
#    'turretKills': 1,
#    'turretTakedowns': 4,
#    'turretsLost': 3,
#    'unrealKills': 0,
#    'visionScore': 84,
#    'visionWardsBoughtInGame': 14,
#    'wardsKilled': 10,
#    'wardsPlaced': 46,
#    'win': True},
#   {'assists': 5,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 165,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 1.5,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 491.0635284138735,
#     'damageTakenOnTeamPercentage': 0.2793875586938757,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earliestBaron': 1612.2662213076646,
#     'earlyLaningPhaseGoldExpAdvantage': -0.23903095722198486,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 10,
#     'enemyJungleMonsterKills': 4,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilledTime': 655.6639047464453,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 374.7792632702674,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 4,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 1.5714285714285714,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.3235294117647059,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 2,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 6,
#     'landSkillShotsEarlyGame': 1,
#     'laneMinionsFirst10Minutes': 51,
#     'laningPhaseGoldExpAdvantage': 0.03935801982879639,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 3,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'moreEnemyJungleThanOpponent': -118.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 3078,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 16,
#     'skillshotsHit': 26,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 3,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 10,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 11,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 5,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.17419755618799307,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 4,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 1.035426378250122,
#     'visionScorePerMinute': 0.5670802209014156,
#     'wardTakedowns': 1,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 18045,
#    'champLevel': 17,
#    'championId': 122,
#    'championName': 'Darius',
#    'championTransform': 0,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 1017,
#    'damageDealtToObjectives': 3281,
#    'damageDealtToTurrets': 1017,
#    'damageSelfMitigated': 27287,
#    'deaths': 7,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 12025,
#    'goldSpent': 11713,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3111,
#    'item1': 1033,
#    'item2': 1028,
#    'item3': 3181,
#    'item4': 3075,
#    'item5': 3078,
#    'item6': 3340,
#    'itemsPurchased': 27,
#    'killingSprees': 2,
#    'kills': 6,
#    'lane': 'TOP',
#    'largestCriticalStrike': 2,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 696,
#    'magicDamageDealt': 273,
#    'magicDamageDealtToChampions': 54,
#    'magicDamageTaken': 8963,
#    'neutralMinionsKilled': 8,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 6,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 316, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 1831, 'var2': 220, 'var3': 0},
#        {'perk': 9105, 'var1': 22, 'var2': 20, 'var3': 0},
#        {'perk': 8299, 'var1': 741, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8473, 'var1': 1115, 'var2': 0, 'var3': 0},
#        {'perk': 8242, 'var1': 80, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 144353,
#    'physicalDamageDealtToChampions': 14504,
#    'physicalDamageTaken': 14733,
#    'profileIcon': 907,
#    'puuid': 'f_M4sPP1tvtQFLy66wH0qRrPSCnKUnGa0tw3wHhBUxifBlozVyP8UQbP_3FTMag_gLcHEyds3jANGg',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 61,
#    'spell2Casts': 81,
#    'spell3Casts': 17,
#    'spell4Casts': 6,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 6,
#    'summoner2Id': 6,
#    'summonerId': 'tsWWBGOjxaECW5-A1GT9UGLDqIHFxxMvtE7aDwXYIth4lgJiPEvZX2nDCQ',
#    'summonerLevel': 35,
#    'summonerName': 'Monsezinaff',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 15,
#    'timePlayed': 1925,
#    'totalDamageDealt': 154184,
#    'totalDamageDealtToChampions': 15756,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 32959,
#    'totalHeal': 5577,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 197,
#    'totalTimeCCDealt': 85,
#    'totalTimeSpentDead': 152,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 9557,
#    'trueDamageDealtToChampions': 1197,
#    'trueDamageTaken': 9261,
#    'turretKills': 0,
#    'turretTakedowns': 1,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionScore': 18,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 1,
#    'wardsPlaced': 10,
#    'win': False},
#   {'assists': 7,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 265,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 165.50000029802322,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 500,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.11466198340466704,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 625.2460174549693,
#     'damageTakenOnTeamPercentage': 0.23570775390698825,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 6,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 3,
#     'earliestBaron': 1612.2662213076646,
#     'earliestDragonTakedown': 485.36091718154887,
#     'earlyLaningPhaseGoldExpAdvantage': 0.03254413604736328,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 7,
#     'enemyJungleMonsterKills': 8,
#     'epicMonsterKillsNearEnemyJungler': 1,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilledTime': 655.6639047464453,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'goldPerMinute': 496.0666175493464,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 1,
#     'initialBuffCount': 2,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 84.00000008940697,
#     'junglerKillsEarlyJungle': 1,
#     'junglerTakedownsNearDamagedEpicMonster': 1,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 2.1666666666666665,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.38235294117647056,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnLanersEarlyJungleAsJungler': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 2,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 2,
#     'landSkillShotsEarlyGame': 2,
#     'laneMinionsFirst10Minutes': 3,
#     'laningPhaseGoldExpAdvantage': 0.07402944564819336,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 99.40000003576279,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 3,
#     'moreEnemyJungleThanOpponent': -34,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 3152,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 10,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 1,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 4,
#     'skillshotsDodged': 11,
#     'skillshotsHit': 24,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 2,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 2,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 1,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 13,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 8,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.22179681844572885,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 4,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 2.144282579421997,
#     'visionScorePerMinute': 1.006880286508137,
#     'wardTakedowns': 7,
#     'wardTakedownsBefore20M': 4,
#     'wardsGuarded': 0},
#    'champExperience': 21532,
#    'champLevel': 18,
#    'championId': 131,
#    'championName': 'Diana',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 2141,
#    'damageDealtToObjectives': 45074,
#    'damageDealtToTurrets': 2141,
#    'damageSelfMitigated': 23192,
#    'deaths': 6,
# ...
#    'turretTakedowns': 1,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionScore': 28,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 11,
#    'wardsPlaced': 10,
#    'win': False},
#   {'assists': 5,
#    'baronKills': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 87,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 4,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 900,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.1021785586132402,
#     'controlWardsPlaced': 3,
#     'damagePerMinute': 655.0652005435676,
#     'damageTakenOnTeamPercentage': 0.1564395626817538,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestBaron': 1612.2662213076646,
#     'earliestDragonTakedown': 1134.8081942964498,
#     'earlyLaningPhaseGoldExpAdvantage': -0.07344949245452881,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 9,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilledTime': 655.6639047464453,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 465.9183975919313,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 6,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 2.142857142857143,
#     'killAfterHiddenWithAlly': 2,
#     'killParticipation': 0.4411764705882353,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 2,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 6,
#     'laneMinionsFirst10Minutes': 71,
#     'laningPhaseGoldExpAdvantage': -0.0875692367553711,
#     'legendaryCount': 1,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 29,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'moreEnemyJungleThanOpponent': -118.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6671,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 14,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 1,
#     'skillshotsDodged': 15,
#     'skillshotsHit': 42,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 1,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 15,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 11,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.23237473458284058,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 5,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.8785629868507385,
#     'visionScorePerMinute': 0.4991004269408267,
#     'wardTakedowns': 4,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 0},
#    'champExperience': 14808,
#    'champLevel': 16,
#    'championId': 51,
#    'championName': 'Caitlyn',
#    'championTransform': 0,
#    'consumablesPurchased': 5,
#    'damageDealtToBuildings': 4341,
#    'damageDealtToObjectives': 14226,
#    'damageDealtToTurrets': 4341,
#    'damageSelfMitigated': 7267,
#    'deaths': 7,
#    'detectorWardsPlaced': 3,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': True,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 14949,
#    'goldSpent': 14175,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 1055,
#    'item1': 6671,
#    'item2': 3036,
#    'item3': 3006,
#    'item4': 3094,
#    'item5': 3031,
#    'item6': 3363,
#    'itemsPurchased': 21,
#    'killingSprees': 4,
#    'kills': 10,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 1245,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 557,
#    'magicDamageDealt': 4497,
#    'magicDamageDealtToChampions': 1514,
#    'magicDamageTaken': 9301,
#    'neutralMinionsKilled': 8,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 1345, 'var2': 1058, 'var3': 0},
#        {'perk': 8009, 'var1': 1395, 'var2': 0, 'var3': 0},
#        {'perk': 9103, 'var1': 20, 'var2': 50, 'var3': 0},
#        {'perk': 8014, 'var1': 526, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8233, 'var1': 20, 'var2': 10, 'var3': 0},
#        {'perk': 8236, 'var1': 28, 'var2': 0, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 179907,
#    'physicalDamageDealtToChampions': 18930,
#    'physicalDamageTaken': 6947,
#    'profileIcon': 3381,
#    'puuid': '7KJkmQBQLZSh90edRGRrReBO8t_UU49-eraA2AO1llR8Q3EqjgXIXCeBr7FRwxbk5AqCJUb3CXFXzA',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 47,
#    'spell2Casts': 23,
#    'spell3Casts': 10,
#    'spell4Casts': 7,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 4,
#    'summoner2Id': 1,
#    'summonerId': 'LxrJmIG9AzL-rYi5-mYYqrx_urCJ33pYpCs3NR0ru5UTI6Axl5Y7WAVkhg',
#    'summonerLevel': 35,
#    'summonerName': 'Enanastynni',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 14,
#    'timePlayed': 1925,
#    'totalDamageDealt': 186630,
#    'totalDamageDealtToChampions': 21018,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 18454,
#    'totalHeal': 1331,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 212,
#    'totalTimeCCDealt': 83,
#    'totalTimeSpentDead': 250,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 2225,
#    'trueDamageDealtToChampions': 573,
#    'trueDamageTaken': 2205,
#    'turretKills': 1,
#    'turretTakedowns': 1,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionScore': 16,
#    'visionWardsBoughtInGame': 3,
#    'wardsKilled': 4,
#    'wardsPlaced': 6,
#    'win': False},
#   {'assists': 15,
#    'baronKills': 1,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'abilityUses': 182,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 1,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 567.0951499297531,
#     'damageTakenOnTeamPercentage': 0.14648639063009908,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 9,
#     'dodgeSkillShotsSmallWindow': 20,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestBaron': 1612.2662213076646,
#     'earliestDragonTakedown': 1134.8081942964498,
#     'earlyLaningPhaseGoldExpAdvantage': -0.13414204120635986,
#     'effectiveHealAndShielding': 3473.442626953125,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 13,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 1,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'fasterSupportQuestCompletion': 1,
#     'firstTurretKilledTime': 655.6639047464453,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1925.1855681938707,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 336.3038630906673,
#     'hadAfkTeammate': 0,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 7,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 2.2222222222222223,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.5882352941176471,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 2,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 2,
#     'laneMinionsFirst10Minutes': 4,
#     'laningPhaseGoldExpAdvantage': -0.025463759899139404,
#     'legendaryCount': 0,
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 19,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 2,
#     'moreEnemyJungleThanOpponent': -118.00000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'mythicItemUsed': 6655,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 2,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 18,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 28,
#     'skillshotsHit': 42,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 0,
#     'stealthWardsPlaced': 28,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 20,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirst25Minutes': 15,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.20116865441607004,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'threeWardsOneSweeperCount': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 5,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.7123339772224426,
#     'visionScorePerMinute': 1.8663552619631263,
#     'wardTakedowns': 5,
#     'wardTakedownsBefore20M': 3,
#     'wardsGuarded': 0},
#    'champExperience': 12666,
#    'champLevel': 14,
#    'championId': 99,
#    'championName': 'Lux',
#    'championTransform': 0,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 1130,
#    'damageDealtToObjectives': 7782,
#    'damageDealtToTurrets': 1130,
#    'damageSelfMitigated': 11989,
#    'deaths': 9,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': True,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'goldEarned': 10790,
#    'goldSpent': 10250,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3853,
#    'item1': 6655,
#    'item2': 4630,
#    'item3': 4645,
#    'item4': 3020,
#    'item5': 1026,
#    'item6': 3364,
#    'itemsPurchased': 18,
#    'killingSprees': 1,
#    'kills': 5,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 559,
#    'magicDamageDealt': 44800,
#    'magicDamageDealtToChampions': 16446,
#    'magicDamageTaken': 7034,
#    'neutralMinionsKilled': 4,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8229, 'var1': 1217, 'var2': 0, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 299, 'var3': 0},
#        {'perk': 8210, 'var1': 11, 'var2': 0, 'var3': 0},
#        {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8126, 'var1': 620, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 4578,
#    'physicalDamageDealtToChampions': 1181,
#    'physicalDamageTaken': 8732,
#    'profileIcon': 4661,
#    'puuid': 'laiPgSy7or1dJSHQp5RifasZCWWkojLKXYOC2ryHf223n9WjlzZ5dBXC41_eN1qP2OP5PsWTMCmwrg',
#    'quadraKills': 0,
#    'riotIdName': '',
#    'riotIdTagline': '',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 31,
#    'spell2Casts': 37,
#    'spell3Casts': 98,
#    'spell4Casts': 16,
#    'summoner1Casts': 6,
#    'summoner1Id': 3,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'xtohyIa588vOU0w0pCUVuQ_fU41Q82ggGdJjVXMzGtwyczCl',
#    'summonerLevel': 328,
#    'summonerName': 'KawaiiAsuna69',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 32,
#    'timePlayed': 1925,
#    'totalDamageDealt': 52490,
#    'totalDamageDealtToChampions': 18196,
#    'totalDamageShieldedOnTeammates': 3473,
#    'totalDamageTaken': 17280,
#    'totalHeal': 962,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 35,
#    'totalTimeCCDealt': 170,
#    'totalTimeSpentDead': 225,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 3111,
#    'trueDamageDealtToChampions': 567,
#    'trueDamageTaken': 1514,
#    'turretKills': 0,
#    'turretTakedowns': 1,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionScore': 59,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 5,
#    'wardsPlaced': 28,
#    'win': False}],
#  'platformId': 'EUW1',
#  'queueId': 420,
#  'teams': [{'bans': [{'championId': 412, 'pickTurn': 1},
#     {'championId': 360, 'pickTurn': 2},
#     {'championId': 145, 'pickTurn': 3},
#     {'championId': 429, 'pickTurn': 4},
#     {'championId': 54, 'pickTurn': 5}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': True, 'kills': 37},
#     'dragon': {'first': False, 'kills': 2},
#     'inhibitor': {'first': True, 'kills': 1},
#     'riftHerald': {'first': True, 'kills': 2},
#     'tower': {'first': False, 'kills': 9}},
#    'teamId': 100,
#    'win': True},
#   {'bans': [{'championId': 101, 'pickTurn': 6},
#     {'championId': 16, 'pickTurn': 7},
#     {'championId': 121, 'pickTurn': 8},
#     {'championId': 23, 'pickTurn': 9},
#     {'championId': 350, 'pickTurn': 10}],
#    'objectives': {'baron': {'first': True, 'kills': 1},
#     'champion': {'first': False, 'kills': 31},
#     'dragon': {'first': True, 'kills': 3},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': True, 'kills': 3}},
#    'teamId': 200,
#    'win': False}],
#  'tournamentCode': ''}
