# %%
from sqlalchemy import create_engine
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Connection à l'instance de la database
def connect_to_instance_db():
    try:
        conn = create_engine('mysql+pymysql://root:1234@localhost/lol_stats')
        conn = conn.connect()
    except pymysql.err.OperationalError as e:
        raise e
    else:
        print("Connection Successful!")
    
    return conn

# %%
connection = connect_to_instance_db()

# %%
dfParticipants = pd.read_sql("SELECT * FROM participants", connection)
dfParticipants.head()
# Out:
#    id  assists  baronKills  basicPings  bountyLevel  champExperience  \
# 0   1        7           0         NaN            0            14091
# 1   2        5           0         NaN            0            11051
# 2   3        2           0         NaN            0            11453
# 3   4        4           0         NaN            3            11420
# 4   5        9           0         NaN            0            10257
#
#    champLevel  championId championName  championTransform  \
# 0          15          10        Kayle                  0
# 1          13         246       Qiyana                  0
# 2          14         145        Kaisa                  0
# 3          13          29       Twitch                  0
# 4          13          43        Karma                  0
#
#    consumablesPurchased  damageDealtToBuildings  damageDealtToObjectives  \
# 0                     8                    4027                     5110
# ...

# %%
a = pd.read_sql("SELECT * FROM participants WHERE summonerName = 'ipj'", connection)
a
# Out:
#      id  assists  baronKills  basicPings  bountyLevel  champExperience  \
# 0   201        1           0         4.0            0            11045
# 1   211        6           1         2.0            3            19770
# 2   221        2           0        11.0            0            13683
# 3   231        3           0         1.0            9            12992
# 4   250        5           0         1.0            0             5467
# 5   255       26           0         NaN            0            12722
# 6   270        3           0         NaN            0             6320
# 7   275       22           0         NaN            0            10293
# 8   290        6           0         NaN            1             4531
# 9   300       22           0         NaN            1             9362
# 10  310       28           0         NaN            0            19136
# 11  320        7           0         NaN            1            11574
# ...

# %%
analyzeList = ['assists', 'basicPings', 'champExperience', 'champLevel', 'championName', 'damageDealtToObjectives', 'deaths', 'detectorWardsPlaced', 'goldEarned', 'individualPosition', 'inhibitorTakedowns', 'inhibitorsLost', 'item0', 'item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'itemsPurchased', 'kills', 'lane', 'longestTimeSpentLiving', 'totalDamageDealtToChampions', 'turretTakedowns', 'turretsLost', 'visionScore', 'wardsKilled', 'wardsPlaced', 'win', 'bans', 'perk0', 'perk1', 'perk2', 'perk3', 'perk4', 'perk5']

# %%
dfParticipants[dfParticipants['championName'] == "Yone"][analyzeList]
# Out:
#      assists  basicPings  champExperience  champLevel championName  \
# 25         1         NaN            13338          15         Yone
# 97         4         NaN            19293          18         Yone
# 152        4         NaN            17540          17         Yone
#
#      damageDealtToObjectives  deaths  detectorWardsPlaced  goldEarned  \
# 25                      5534       3                    0        9004
# 97                     16270      11                    2       14650
# 152                    17627      11                    0       14738
#
#     individualPosition  inhibitorTakedowns  inhibitorsLost  item0  item1  \
# 25                 TOP                   0               1   3031   3006
# 97              MIDDLE                   0               1   6333   3006
# 152             MIDDLE                   2               0   3140   3031
#
#      item2  item3  item4  item5  item6  itemsPurchased  kills    lane  \
# ...
