# %%
import requests
import json
import pandas as pd
from itertools import zip_longest

# %%
import pymysql

# %%
from secrets import RIOT_API_KEY

# %% [markdown]
# ### Collecting user informations

# %%
def summonerDetails(url):
    response = requests.get(url, headers=header)
    
    return response.json()

def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.134 Safari/537.36 Edg/103.0.1264.77",
    "Accept-Language": "fr,fr-FR;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": RIOT_API_KEY
}

# %%
summonerName = "Yoshigaï"
summoner = f"https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summonerName}"

# %%
summonerDetails(summoner)
# Out:
# {'id': 'npeXbTTF7WpCjn6P3m0V6JjeJjiTm27S4pJ4BWZsQbtdKok3',
#  'accountId': 'zSHEEQxOgB2Lg5A1FggIK4oEP0trE10kXjPz4kNyjDpWHEHx1z2Wn138',
#  'puuid': 'OOLWF-QQsUv2WmdnK3KNSA_J-RFuN4Ai9D9LFjpp98_UEgpxQyBUbD_z_SXaZTYp1iYZ9007UowQ1A',
#  'name': 'Yoshigaï',
#  'profileIconId': 2073,
#  'revisionDate': 1659903371000,
#  'summonerLevel': 112}

# %% [markdown]
# ### Collecting the last 20 games

# %%
puuid = "OOLWF-QQsUv2WmdnK3KNSA_J-RFuN4Ai9D9LFjpp98_UEgpxQyBUbD_z_SXaZTYp1iYZ9007UowQ1A"
matchsUrl = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?queue=420&start=0&count=20"

# %%
summonerDetails(matchsUrl)
# Out:
# ['EUW1_6005214349',
#  'EUW1_6005136684',
#  'EUW1_5999047056',
#  'EUW1_5990865236',
#  'EUW1_5990860944',
#  'EUW1_5989568935',
#  'EUW1_5989043595',
#  'EUW1_5988969621',
#  'EUW1_5987485024',
#  'EUW1_5987009550',
#  'EUW1_5986003034',
#  'EUW1_5985914039',
#  'EUW1_5985777899',
#  'EUW1_5985744417',
#  'EUW1_5984936673',
#  'EUW1_5984893094',
#  'EUW1_5982758252',
#  'EUW1_5982821903',
#  'EUW1_5982545626',
#  'EUW1_5982349147']

# %% [markdown]
# ### Collecting the details of a game

# %%
match = "EUW1_5999047056"
matchDetailsUrl = f"https://europe.api.riotgames.com/lol/match/v5/matches/{match}"

# %%
matchDetails = summonerDetails(matchDetailsUrl)
matchDetails
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_5999047056',
#   'participants': ['2eXbDgouDlZw2Mo-4PahdMRHt0lY_--pf50uB2MCECuE68rWyEHLDt8ILn1LCe6qcnq6RtB_tpLhKw',
#    'jpSEbCAgVRc0r3YhOyGLrjQeaMiSSyrKZ_LzgnHGMx42FHY6KAlJXbLK4FR1e2li_JNO3a_L7OpqHg',
#    'iriERqj804qjtJFhOIDaUKgRNbeZSJcMvKmtHgnPdGaHoYUnM2hxaJqWg9H1dVdVj9V4V_2udjf7MQ',
#    '8tlGGFtNmIlIil7qxh1sS5wKy5BSXHXoWvuzqgSj6bLM5FVksosPKTZJIrXmU6h7o36Q05inr_mqYQ',
#    'qsAl6tq34mwWDAbzIeX6KXPjTk9mXPqyGS-1U6KjMjl4vcJdFTgLyVqiYMb6ygLv6LNYf2IjmT-SPQ',
#    'SiXIhB6NhkrYp22aCuPemvKUHpLRBM5nLhqr3ariKqnJgV2y4cDydNt3iNQNMvlq8x1P6NlsKQTzqA',
#    'FTF2MEmgpBi8tRo8BvEwuDdHcHS_XhysR5JHwwLykd0TDCHvIftGCIEBTgIlpEQ_huwM-9rTDz7EoQ',
#    'OOLWF-QQsUv2WmdnK3KNSA_J-RFuN4Ai9D9LFjpp98_UEgpxQyBUbD_z_SXaZTYp1iYZ9007UowQ1A',
#    '-eg5MeHR3Jrg4EGgqNbYvjf2RX6kmAV6j3Cvzn-YNSkTAquPopzWU8S-Twu3q23wzQocY9BYkNS8Vg',
#    '6gYNycQgzpdPVBR_22hlt1WhyT0piXTy4YldFnKv6kTotDTZGjr41QOQ69-XzXxPGNvKMgo8Nz9eqQ']},
#  'info': {'gameCreation': 1659541674507,
#   'gameDuration': 2560,
#   'gameEndTimestamp': 1659544429539,
#   'gameId': 5999047056,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-5999047056',
#   'gameStartTimestamp': 1659541868788,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '12.14.456.5556',
#   'mapId': 11,
#   'participants': [{'assists': 5,
#     'baronKills': 0,
#     'basicPings': 98,
#     'bountyLevel': 6,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 211,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 850,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 973.1743646730713,
#      'damageTakenOnTeamPercentage': 0.12755277627794617,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 11,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1384.5220002440565,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 859.4769041629871,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 3,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 389.45167341817836,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.666666666666667,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.3888888888888889,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 68,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 1,
#      'maxKillDeficit': 7,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': -115.00000002980232,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6653,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'shortestTimeToAceFromFirstTakedown': 29.62707034565915,
#      'skillshotsDodged': 84,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 13,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 8,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 14,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 1,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2469467692665513,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.043209195137023926,
#      'visionScorePerMinute': 0.5854246056075978,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 20766,
#     'champLevel': 18,
#     'championId': 17,
#     'championName': 'Teemo',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3401,
#     'damageDealtToObjectives': 15497,
#     'damageDealtToTurrets': 3401,
#     'damageSelfMitigated': 15413,
#     'deaths': 3,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 16621,
#     'goldSpent': 16600,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 4637,
#     'item1': 3115,
#     'item2': 3020,
#     'item3': 6653,
#     'item4': 4645,
#     'item5': 3135,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 687,
#     'magicDamageDealt': 153541,
#     'magicDamageDealtToChampions': 35551,
#     'magicDamageTaken': 7121,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 2389, 'var2': 1304, 'var3': 1084},
#         {'perk': 9111, 'var1': 1239, 'var2': 280, 'var3': 0},
#         {'perk': 9104, 'var1': 26, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 765, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8143, 'var1': 471, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 41828,
#     'physicalDamageDealtToChampions': 3922,
#     'physicalDamageTaken': 16050,
#     'profileIcon': 4404,
#     'puuid': '2eXbDgouDlZw2Mo-4PahdMRHt0lY_--pf50uB2MCECuE68rWyEHLDt8ILn1LCe6qcnq6RtB_tpLhKw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 49,
#     'spell2Casts': 63,
#     'spell3Casts': 0,
#     'spell4Casts': 99,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 7,
#     'summoner2Id': 14,
#     'summonerId': 'jy2Kh65aNtriuJZ57uGqDCLLIdRqtEvgnwnH7RnE29hlPQTK',
#     'summonerLevel': 36,
#     'summonerName': 'SSIO 09',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 60,
#     'timePlayed': 2560,
#     'totalDamageDealt': 201125,
#     'totalDamageDealtToChampions': 41533,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23275,
#     'totalHeal': 4948,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 198,
#     'totalTimeCCDealt': 408,
#     'totalTimeSpentDead': 108,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5754,
#     'trueDamageDealtToChampions': 2059,
#     'trueDamageTaken': 103,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 24,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 13,
#     'win': True},
#    {'assists': 18,
#     'baronKills': 2,
#     'basicPings': 38,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 515,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 143.6000002026558,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1150,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.2906226356796383,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 867.372653625462,
#      'damageTakenOnTeamPercentage': 0.31837655765071726,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 65,
#      'doubleAces': 0,
#      'dragonTakedowns': 3,
#      'earliestBaron': 1384.5220002440565,
#      'earliestDragonTakedown': 990.2062676128353,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 36,
#      'enemyJungleMonsterKills': 14.000000029802322,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 859.4769041629871,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 3,
#      'gameLength': 2560.729203406602,
#      'goldPerMinute': 447.7948874043538,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 16,
#      'initialBuffCount': 2,
#      'initialCrabCount': 2,
#      'jungleCsBefore10Minutes': 68.00000011920929,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.25,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.7222222222222222,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnLanersEarlyJungleAsJungler': 2,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 2,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 63.10000002384186,
#      'maxKillDeficit': 7,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -46.99999991059303,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6664,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 2,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 5,
#      'skillshotsDodged': 385,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 2,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.22009917476085597,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 1,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.5848795175552368,
#      'visionScorePerMinute': 0.624653165956399,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 22147,
#     'champLevel': 18,
#     'championId': 106,
#     'championName': 'Volibear',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 871,
#     'damageDealtToObjectives': 50988,
#     'damageDealtToTurrets': 871,
#     'damageSelfMitigated': 115418,
#     'deaths': 8,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 1,
#     'dragonKills': 3,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 19111,
#     'goldSpent': 18200,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 4401,
#     'item1': 3742,
#     'item2': 3111,
#     'item3': 3075,
#     'item4': 3110,
#     'item5': 6664,
#     'item6': 3364,
#     'itemsPurchased': 27,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 35,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 697,
#     'magicDamageDealt': 159481,
#     'magicDamageDealtToChampions': 16643,
#     'magicDamageTaken': 15829,
#     'neutralMinionsKilled': 215,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 3383, 'var2': 1815, 'var3': 1567},
#         {'perk': 9111, 'var1': 3357, 'var2': 500, 'var3': 0},
#         {'perk': 9105, 'var1': 10, 'var2': 40, 'var3': 0},
#         {'perk': 8299, 'var1': 1508, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8234, 'var1': 18906, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 9, 'var2': 50, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 101473,
#     'physicalDamageDealtToChampions': 17966,
#     'physicalDamageTaken': 40166,
#     'profileIcon': 4248,
#     'puuid': 'jpSEbCAgVRc0r3YhOyGLrjQeaMiSSyrKZ_LzgnHGMx42FHY6KAlJXbLK4FR1e2li_JNO3a_L7OpqHg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 151,
#     'spell2Casts': 218,
#     'spell3Casts': 134,
#     'spell4Casts': 12,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 26,
#     'summoner2Id': 11,
#     'summonerId': 'LtjYQFySKzP8eTT6UxYtNJchUF5NhKM9px66UFmn_0jCavU',
#     'summonerLevel': 312,
#     'summonerName': 'Erîdu',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 54,
#     'timePlayed': 2560,
#     'totalDamageDealt': 287037,
#     'totalDamageDealtToChampions': 37018,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 58095,
#     'totalHeal': 15353,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 54,
#     'totalTimeCCDealt': 957,
#     'totalTimeSpentDead': 368,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 26082,
#     'trueDamageDealtToChampions': 2408,
#     'trueDamageTaken': 2099,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 1,
#     'wardsPlaced': 6,
#     'win': True},
#    {'assists': 9,
#     'baronKills': 0,
#     'basicPings': 35,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 476,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 11,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.10152251231234236,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 868.5354998846599,
#      'damageTakenOnTeamPercentage': 0.22641342337781772,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 17,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1384.5220002440565,
#      'earliestDragonTakedown': 990.2062676128353,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 46,
#      'enemyJungleMonsterKills': 5.5,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 859.4769041629871,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 3,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 465.044597322426,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 8,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.75,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.6111111111111112,
#      'killedChampTookFullTeamDamageSurvived': 1,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 71,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 50,
#      'maxKillDeficit': 7,
#      'maxLevelLeadLaneOpponent': 3,
#      'moreEnemyJungleThanOpponent': -115.00000002980232,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6673,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 6,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 29.62707034565915,
#      'skillshotsDodged': 123,
#      'skillshotsHit': 5,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 3,
#      'stealthWardsPlaced': 11,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.22039425150895656,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 4,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 1.0375127792358398,
#      'visionScorePerMinute': 0.6046475735431246,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 22945,
#     'champLevel': 18,
#     'championId': 777,
#     'championName': 'Yone',
#     'championTransform': 0,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 6609,
#     'damageDealtToObjectives': 46547,
#     'damageDealtToTurrets': 6609,
#     'damageSelfMitigated': 64743,
#     'deaths': 8,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 19847,
#     'goldSpent': 19300,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3031,
#     'item1': 6333,
#     'item2': 3033,
#     'item3': 3006,
#     'item4': 6673,
#     'item5': 3026,
#     'item6': 3340,
#     'itemsPurchased': 32,
#     'killingSprees': 3,
#     'kills': 13,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 878,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 991,
#     'magicDamageDealt': 50817,
#     'magicDamageDealtToChampions': 9420,
#     'magicDamageTaken': 11101,
#     'neutralMinionsKilled': 24,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 56, 'var2': 4, 'var3': 0},
#         {'perk': 9111, 'var1': 1690, 'var2': 440, 'var3': 0},
#         {'perk': 9104, 'var1': 16, 'var2': 30, 'var3': 0},
#         {'perk': 8299, 'var1': 1689, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 1339, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 88, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 233180,
#     'physicalDamageDealtToChampions': 23701,
#     'physicalDamageTaken': 24753,
#     'profileIcon': 5435,
#     'puuid': 'iriERqj804qjtJFhOIDaUKgRNbeZSJcMvKmtHgnPdGaHoYUnM2hxaJqWg9H1dVdVj9V4V_2udjf7MQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 315,
#     'spell2Casts': 96,
#     'spell3Casts': 51,
#     'spell4Casts': 14,
#     'summoner1Casts': 6,
#     'summoner1Id': 12,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'WuOz8rkC9nddpWplfMRtnOCOugbXifbI7IaY_lgoLjeYDS4',
#     'summonerLevel': 307,
#     'summonerName': 'Antideus',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 25,
#     'timePlayed': 2560,
#     'totalDamageDealt': 294732,
#     'totalDamageDealtToChampions': 37068,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 41314,
#     'totalHeal': 7593,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 254,
#     'totalTimeCCDealt': 179,
#     'totalTimeSpentDead': 404,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 10734,
#     'trueDamageDealtToChampions': 3945,
#     'trueDamageTaken': 5460,
#     'turretKills': 3,
#     'turretTakedowns': 3,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 25,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 1,
#     'wardsPlaced': 12,
#     'win': True},
#    {'assists': 10,
#     'baronKills': 0,
#     'basicPings': 46,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 252,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 18.40000006556511,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1057.7579984918511,
#      'damageTakenOnTeamPercentage': 0.2116691448005668,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 14,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1384.5220002440565,
#      'earliestDragonTakedown': 2394.2942222107336,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 432.00006103515625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 14,
#      'enemyJungleMonsterKills': 7.600000023841858,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 859.4769041629871,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 3,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 378.30400038933004,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.7,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.4722222222222222,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 48,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 32.00000008940697,
#      'maxKillDeficit': 7,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -115.00000002980232,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 29.62707034565915,
#      'skillshotsDodged': 111,
#      'skillshotsHit': 48,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 8,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 17,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2684101943860464,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.30667877197265625,
#      'visionScorePerMinute': 0.422660076416367,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 19578,
#     'champLevel': 18,
#     'championId': 222,
#     'championName': 'Jinx',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 5423,
#     'damageDealtToObjectives': 25759,
#     'damageDealtToTurrets': 5423,
#     'damageSelfMitigated': 19724,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 16145,
#     'goldSpent': 15150,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 6672,
#     'item1': 3094,
#     'item2': 3031,
#     'item3': 3026,
#     'item4': 3035,
#     'item5': 3006,
#     'item6': 3340,
#     'itemsPurchased': 19,
#     'killingSprees': 1,
#     'kills': 7,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 880,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 452,
#     'magicDamageDealt': 10602,
#     'magicDamageDealtToChampions': 4336,
#     'magicDamageTaken': 16673,
#     'neutralMinionsKilled': 30,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 90, 'var2': 17, 'var3': 0},
#         {'perk': 8009, 'var1': 3216, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 28, 'var2': 40, 'var3': 0},
#         {'perk': 8014, 'var1': 777, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 21, 'var2': 30, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 269859,
#     'physicalDamageDealtToChampions': 36587,
#     'physicalDamageTaken': 21209,
#     'profileIcon': 907,
#     'puuid': '8tlGGFtNmIlIil7qxh1sS5wKy5BSXHXoWvuzqgSj6bLM5FVksosPKTZJIrXmU6h7o36Q05inr_mqYQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 161,
#     'spell2Casts': 59,
#     'spell3Casts': 23,
#     'spell4Casts': 9,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 7,
#     'summoner2Id': 7,
#     'summonerId': 'K5H6au2pR1DOxV-_G4nsymcmCjyDCmTPVUMV3sWiPTKQbZGuG0TDB89dsw',
#     'summonerLevel': 32,
#     'summonerName': 'Prneytonev',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 30,
#     'timePlayed': 2560,
#     'totalDamageDealt': 303273,
#     'totalDamageDealtToChampions': 45143,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 38624,
#     'totalHeal': 6647,
#     'totalHealsOnTeammates': 432,
#     'totalMinionsKilled': 256,
#     'totalTimeCCDealt': 115,
#     'totalTimeSpentDead': 410,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 22811,
#     'trueDamageDealtToChampions': 4219,
#     'trueDamageTaken': 741,
#     'turretKills': 2,
#     'turretTakedowns': 4,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 9,
#     'win': True},
#    {'assists': 17,
#     'baronKills': 0,
#     'basicPings': 7,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 175,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.005159403976002523,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 173.98595197431422,
#      'damageTakenOnTeamPercentage': 0.115988097892952,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 22,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1384.5220002440565,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 5971.13427734375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 19,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 859.4769041629871,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 3,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 226.16979905744407,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.8888888888888888,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.4722222222222222,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 1,
#      'laneMinionsFirst10Minutes': 0,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 1,
#      'maxKillDeficit': 7,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': -115.00000002980232,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 2065,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 2,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 139,
#      'skillshotsHit': 17,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 27,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 3,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 17,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.04414961007758977,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.40624386072158813,
#      'visionScorePerMinute': 1.1030396625723746,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15085,
#     'champLevel': 16,
#     'championId': 267,
#     'championName': 'Nami',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 743,
#     'damageDealtToObjectives': 1737,
#     'damageDealtToTurrets': 743,
#     'damageSelfMitigated': 8652,
#     'deaths': 9,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 9652,
#     'goldSpent': 8875,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 3853,
#     'item1': 3158,
#     'item2': 2065,
#     'item3': 3011,
#     'item4': 6616,
#     'item5': 1004,
#     'item6': 3340,
#     'itemsPurchased': 23,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 670,
#     'magicDamageDealt': 18591,
#     'magicDamageDealtToChampions': 6300,
#     'magicDamageTaken': 6521,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 973, 'var2': 0, 'var3': 0},
#         {'perk': 8126, 'var1': 326, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8105, 'var1': 13, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 296, 'var3': 0},
#         {'perk': 8237, 'var1': 475, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 3030,
#     'physicalDamageDealtToChampions': 483,
#     'physicalDamageTaken': 14157,
#     'profileIcon': 5434,
#     'puuid': 'qsAl6tq34mwWDAbzIeX6KXPjTk9mXPqyGS-1U6KjMjl4vcJdFTgLyVqiYMb6ygLv6LNYf2IjmT-SPQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 60,
#     'spell2Casts': 61,
#     'spell3Casts': 44,
#     'spell4Casts': 10,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 2,
#     'summoner2Id': 14,
#     'summonerId': 'Z9Txg9-XXdZD7Di5nInMWA3lc5PZYclMkw5x1kDJ2Q6AKKs',
#     'summonerLevel': 142,
#     'summonerName': 'RudeDolly',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 30,
#     'timePlayed': 2560,
#     'totalDamageDealt': 22263,
#     'totalDamageDealtToChampions': 7425,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21164,
#     'totalHeal': 8331,
#     'totalHealsOnTeammates': 5971,
#     'totalMinionsKilled': 11,
#     'totalTimeCCDealt': 199,
#     'totalTimeSpentDead': 287,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 641,
#     'trueDamageDealtToChampions': 641,
#     'trueDamageTaken': 485,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionScore': 47,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 28,
#     'win': True},
#    {'assists': 17,
#     'baronKills': 0,
#     'basicPings': 37,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 254,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 1.5,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 728.7472844229089,
#      'damageTakenOnTeamPercentage': 0.2732658606839637,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1713.3699808290241,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 46,
#      'enemyJungleMonsterKills': 4,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 365.103292772519,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.4285714285714284,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.631578947368421,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 2,
#      'knockEnemyIntoTeamAndKill': 4,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 77,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 55.75,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -131.0000001192093,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3078,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 54,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.21466844556531056,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 2,
#      'tookLargeDamageSurvived': 1,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.04141950607299805,
#      'visionScorePerMinute': 0.561176609332765,
#      'wardTakedowns': 14,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 19262,
#     'champLevel': 18,
#     'championId': 150,
#     'championName': 'Gnar',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 3081,
#     'damageDealtToObjectives': 13399,
#     'damageDealtToTurrets': 3081,
#     'damageSelfMitigated': 74147,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 15582,
#     'goldSpent': 14508,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 4401,
#     'item1': 3111,
#     'item2': 3078,
#     'item3': 3071,
#     'item4': 3075,
#     'item5': 1037,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 1,
#     'kills': 7,
#     'lane': 'TOP',
#     'largestCriticalStrike': 16,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1266,
#     'magicDamageDealt': 24472,
#     'magicDamageDealtToChampions': 6353,
#     'magicDamageTaken': 20050,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 4385, 'var2': 3482, 'var3': 0},
#         {'perk': 9111, 'var1': 1837, 'var2': 480, 'var3': 0},
#         {'perk': 9104, 'var1': 19, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 915, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 1315, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 255, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 158438,
#     'physicalDamageDealtToChampions': 24360,
#     'physicalDamageTaken': 35141,
#     'profileIcon': 4492,
#     'puuid': 'SiXIhB6NhkrYp22aCuPemvKUHpLRBM5nLhqr3ariKqnJgV2y4cDydNt3iNQNMvlq8x1P6NlsKQTzqA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 162,
#     'spell2Casts': 36,
#     'spell3Casts': 46,
#     'spell4Casts': 10,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': '0fP9kwQYNlm93-k5UepThipQbGorLlZDduv8RytX9CfWKjY',
#     'summonerLevel': 93,
#     'summonerName': 'Tooooooooooooor',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 40,
#     'timePlayed': 2560,
#     'totalDamageDealt': 187672,
#     'totalDamageDealtToChampions': 31102,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 59893,
#     'totalHeal': 11356,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 214,
#     'totalTimeCCDealt': 564,
#     'totalTimeSpentDead': 352,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4761,
#     'trueDamageDealtToChampions': 388,
#     'trueDamageTaken': 4702,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionScore': 23,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 7,
#     'wardsPlaced': 4,
#     'win': False},
#    {'assists': 14,
#     'baronKills': 0,
#     'basicPings': 13,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 269,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 145.00000023841858,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 450,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 897.7659127590175,
#      'damageTakenOnTeamPercentage': 0.24551699036810984,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 3,
#      'earliestDragonTakedown': 577.2011169573992,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 69,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
# ...
#      'abilityUses': 199,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 12,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 750,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.05296364126344088,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 1151.8372490641138,
#      'damageTakenOnTeamPercentage': 0.14141786914732835,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1337.3178523488914,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 605.2412109375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 491.38102862499494,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.2857142857142856,
#      'killAfterHiddenWithAlly': 8,
#      'killParticipation': 0.6052631578947368,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 4,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 9,
#      'laneMinionsFirst10Minutes': 75,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 39,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -131.0000001192093,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 4,
#      'multikillsAfterAggressiveFlash': 1,
#      'mythicItemUsed': 6692,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 1,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 16,
#      'skillshotsHit': 206,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 17,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.3392988448617316,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.4423328638076782,
#      'visionScorePerMinute': 0.609616514986612,
#      'wardTakedowns': 5,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17892,
#     'champLevel': 17,
#     'championId': 21,
#     'championName': 'MissFortune',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 642,
#     'damageDealtToObjectives': 11021,
#     'damageDealtToTurrets': 642,
#     'damageSelfMitigated': 19820,
#     'deaths': 7,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 4,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 20971,
#     'goldSpent': 17525,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 3142,
#     'item1': 6692,
#     'item2': 6676,
#     'item3': 3036,
#     'item4': 3006,
#     'item5': 3031,
#     'item6': 3340,
#     'itemsPurchased': 26,
#     'killingSprees': 5,
#     'kills': 17,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 1187,
#     'largestKillingSpree': 7,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 523,
#     'magicDamageDealt': 4578,
#     'magicDamageDealtToChampions': 1892,
#     'magicDamageTaken': 11258,
#     'neutralMinionsKilled': 16,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 2023, 'var2': 1477, 'var3': 0},
#         {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 31, 'var2': 0, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 258726,
#     'physicalDamageDealtToChampions': 44492,
#     'physicalDamageTaken': 19356,
#     'profileIcon': 4637,
#     'puuid': '-eg5MeHR3Jrg4EGgqNbYvjf2RX6kmAV6j3Cvzn-YNSkTAquPopzWU8S-Twu3q23wzQocY9BYkNS8Vg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 118,
#     'spell2Casts': 21,
#     'spell3Casts': 43,
#     'spell4Casts': 17,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 7,
#     'summonerId': 'A-3gLz2dmWYODFW8H6BPrSFpv9IDfpK4l4c7EYW3qepqJcA',
#     'summonerLevel': 359,
#     'summonerName': 'Arliming',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 15,
#     'timePlayed': 2560,
#     'totalDamageDealt': 299387,
#     'totalDamageDealtToChampions': 49159,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 30995,
#     'totalHeal': 8647,
#     'totalHealsOnTeammates': 605,
#     'totalMinionsKilled': 279,
#     'totalTimeCCDealt': 201,
#     'totalTimeSpentDead': 267,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 36080,
#     'trueDamageDealtToChampions': 2773,
#     'trueDamageTaken': 380,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 0,
#     'wardsPlaced': 18,
#     'win': False},
#    {'assists': 29,
#     'baronKills': 0,
#     'basicPings': 23,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 2,
#      'abilityUses': 225,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 216.82424026869617,
#      'damageTakenOnTeamPercentage': 0.1336075211158832,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 577.2011169573992,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 32028.26953125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 13,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 2560.729203406602,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 242.38738567339828,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.7894736842105263,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 3,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 24,
#      'laneMinionsFirst10Minutes': 1,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'moreEnemyJungleThanOpponent': -131.0000001192093,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6617,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 26,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 8,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 11,
#      'skillshotsHit': 75,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 33,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 30,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.06387032049967693,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.6841931343078613,
#      'visionScorePerMinute': 1.8577318830056517,
#      'wardTakedowns': 10,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 17227,
#     'champLevel': 17,
#     'championId': 16,
#     'championName': 'Soraka',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 135,
#     'damageDealtToObjectives': 1100,
#     'damageDealtToTurrets': 135,
#     'damageSelfMitigated': 19938,
#     'deaths': 6,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 10344,
#     'goldSpent': 9725,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 2,
#     'item0': 3853,
#     'item1': 6617,
#     'item2': 3158,
#     'item3': 3011,
#     'item4': 3083,
#     'item5': 1028,
#     'item6': 3364,
#     'itemsPurchased': 22,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 959,
#     'magicDamageDealt': 16461,
#     'magicDamageDealtToChampions': 8889,
#     'magicDamageTaken': 10249,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 991, 'var2': 2398, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 365, 'var3': 0},
#         {'perk': 8210, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 862, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 697, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 4562, 'var2': 340, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 2007,
#     'physicalDamageDealtToChampions': 283,
#     'physicalDamageTaken': 17562,
#     'profileIcon': 4896,
#     'puuid': '6gYNycQgzpdPVBR_22hlt1WhyT0piXTy4YldFnKv6kTotDTZGjr41QOQ69-XzXxPGNvKMgo8Nz9eqQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 69,
#     'spell2Casts': 84,
#     'spell3Casts': 58,
#     'spell4Casts': 14,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 3,
#     'summonerId': '_KLmEhzAfl3ewQeIP_T-PSds0M-U196qYUst1dVRftkRb7UdJMkX_1ADXQ',
#     'summonerLevel': 188,
#     'summonerName': 'ChoReeSo',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 70,
#     'timePlayed': 2560,
#     'totalDamageDealt': 18550,
#     'totalDamageDealtToChampions': 9253,
#     'totalDamageShieldedOnTeammates': 2931,
#     'totalDamageTaken': 29283,
#     'totalHeal': 42284,
#     'totalHealsOnTeammates': 29096,
#     'totalMinionsKilled': 15,
#     'totalTimeCCDealt': 258,
#     'totalTimeSpentDead': 232,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 81,
#     'trueDamageDealtToChampions': 81,
#     'trueDamageTaken': 1471,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionScore': 79,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 4,
#     'wardsPlaced': 34,
#     'win': False}],
#   'platformId': 'EUW1',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 84, 'pickTurn': 1},
#      {'championId': 39, 'pickTurn': 2},
#      {'championId': 107, 'pickTurn': 3},
#      {'championId': 555, 'pickTurn': 4},
#      {'championId': 25, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 2},
#      'champion': {'first': True, 'kills': 37},
#      'dragon': {'first': False, 'kills': 3},
#      'inhibitor': {'first': False, 'kills': 2},
#      'riftHerald': {'first': True, 'kills': 2},
#      'tower': {'first': True, 'kills': 10}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 25, 'pickTurn': 6},
#      {'championId': 555, 'pickTurn': 7},
#      {'championId': -1, 'pickTurn': 8},
#      {'championId': 895, 'pickTurn': 9},
#      {'championId': 122, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 38},
#      'dragon': {'first': True, 'kills': 3},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 6}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
matchDetails['info']['teams']
# Out:
# [{'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 39, 'pickTurn': 2},
#    {'championId': 107, 'pickTurn': 3},
#    {'championId': 555, 'pickTurn': 4},
#    {'championId': 25, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': True, 'kills': 2},
#    'champion': {'first': True, 'kills': 37},
#    'dragon': {'first': False, 'kills': 3},
#    'inhibitor': {'first': False, 'kills': 2},
#    'riftHerald': {'first': True, 'kills': 2},
#    'tower': {'first': True, 'kills': 10}},
#   'teamId': 100,
#   'win': True},
#  {'bans': [{'championId': 25, 'pickTurn': 6},
#    {'championId': 555, 'pickTurn': 7},
#    {'championId': -1, 'pickTurn': 8},
#    {'championId': 895, 'pickTurn': 9},
#    {'championId': 122, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': False, 'kills': 0},
#    'champion': {'first': False, 'kills': 38},
#    'dragon': {'first': True, 'kills': 3},
#    'inhibitor': {'first': True, 'kills': 1},
#    'riftHerald': {'first': False, 'kills': 0},
#    'tower': {'first': False, 'kills': 6}},
#   'teamId': 200,
#   'win': False}]

# %%
dictParticipants = matchDetails['info']['participants']
dictParticipants[0]
# Out:
# {'assists': 5,
#  'baronKills': 0,
#  'basicPings': 98,
#  'bountyLevel': 6,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 211,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 850,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 973.1743646730713,
#   'damageTakenOnTeamPercentage': 0.12755277627794617,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 3,
#   'dodgeSkillShotsSmallWindow': 11,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earliestBaron': 1384.5220002440565,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 0,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilledTime': 859.4769041629871,
#   'flawlessAces': 1,
#   'fullTeamTakedown': 3,
#   'gameLength': 2560.729203406602,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 389.45167341817836,
#   'hadOpenNexus': 0,
#   'immobilizeAndKillWithAlly': 0,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 4.666666666666667,
#   'killAfterHiddenWithAlly': 1,
#   'killParticipation': 0.3888888888888889,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 1,
#   'killsNearEnemyTurret': 1,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 1,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 0,
#   'laneMinionsFirst10Minutes': 68,
#   'laningPhaseGoldExpAdvantage': 0,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 1,
#   'maxCsAdvantageOnLaneOpponent': 1,
#   'maxKillDeficit': 7,
#   'maxLevelLeadLaneOpponent': 1,
#   'moreEnemyJungleThanOpponent': -115.00000002980232,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 0,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 6653,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 13,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 1,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 2,
#   'shortestTimeToAceFromFirstTakedown': 29.62707034565915,
#   'skillshotsDodged': 84,
#   'skillshotsHit': 0,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 0,
#   'soloTurretsLategame': 1,
#   'stealthWardsPlaced': 13,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 8,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 14,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 1,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 2,
#   'teamDamagePercentage': 0.2469467692665513,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 2,
#   'threeWardsOneSweeperCount': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 0,
#   'turretTakedowns': 3,
#   'turretsTakenWithRiftHerald': 5,
#   'twentyMinionsIn3SecondsCount': 0,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': 0.043209195137023926,
#   'visionScorePerMinute': 0.5854246056075978,
#   'wardTakedowns': 2,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 20766,
#  'champLevel': 18,
#  'championId': 17,
#  'championName': 'Teemo',
#  'championTransform': 0,
#  'consumablesPurchased': 0,
#  'damageDealtToBuildings': 3401,
#  'damageDealtToObjectives': 15497,
#  'damageDealtToTurrets': 3401,
#  'damageSelfMitigated': 15413,
#  'deaths': 3,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 0,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'goldEarned': 16621,
#  'goldSpent': 16600,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 1,
#  'inhibitorTakedowns': 1,
#  'inhibitorsLost': 1,
#  'item0': 4637,
#  'item1': 3115,
#  'item2': 3020,
#  'item3': 6653,
#  'item4': 4645,
#  'item5': 3135,
#  'item6': 3340,
#  'itemsPurchased': 21,
#  'killingSprees': 2,
#  'kills': 9,
#  'lane': 'TOP',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 6,
#  'largestMultiKill': 1,
#  'longestTimeSpentLiving': 687,
#  'magicDamageDealt': 153541,
#  'magicDamageDealtToChampions': 35551,
#  'magicDamageTaken': 7121,
#  'neutralMinionsKilled': 8,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8005, 'var1': 2389, 'var2': 1304, 'var3': 1084},
#      {'perk': 9111, 'var1': 1239, 'var2': 280, 'var3': 0},
#      {'perk': 9104, 'var1': 26, 'var2': 20, 'var3': 0},
#      {'perk': 8014, 'var1': 765, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8143, 'var1': 471, 'var2': 0, 'var3': 0},
#      {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0}],
#     'style': 8100}]},
#  'physicalDamageDealt': 41828,
#  'physicalDamageDealtToChampions': 3922,
#  'physicalDamageTaken': 16050,
#  'profileIcon': 4404,
#  'puuid': '2eXbDgouDlZw2Mo-4PahdMRHt0lY_--pf50uB2MCECuE68rWyEHLDt8ILn1LCe6qcnq6RtB_tpLhKw',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 49,
#  'spell2Casts': 63,
#  'spell3Casts': 0,
#  'spell4Casts': 99,
#  'summoner1Casts': 5,
#  'summoner1Id': 4,
#  'summoner2Casts': 7,
#  'summoner2Id': 14,
#  'summonerId': 'jy2Kh65aNtriuJZ57uGqDCLLIdRqtEvgnwnH7RnE29hlPQTK',
#  'summonerLevel': 36,
#  'summonerName': 'SSIO 09',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 60,
#  'timePlayed': 2560,
#  'totalDamageDealt': 201125,
#  'totalDamageDealtToChampions': 41533,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 23275,
#  'totalHeal': 4948,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 198,
#  'totalTimeCCDealt': 408,
#  'totalTimeSpentDead': 108,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 5754,
#  'trueDamageDealtToChampions': 2059,
#  'trueDamageTaken': 103,
#  'turretKills': 2,
#  'turretTakedowns': 3,
#  'turretsLost': 6,
#  'unrealKills': 0,
#  'visionScore': 24,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 2,
#  'wardsPlaced': 13,
#  'win': True}

# %% [markdown]
# ### Tables
# - matchs : matchDetails['info']
# - participants :
#     - matchDetails['info']['participants']
#     - matchDetails['info']['teams']
#     - dictParticipants[0]['perks']['styles'])

# %% [markdown]
# ## PRE-PROCESSING
# ### Matchs Table

# %%
dictInfos = matchDetails['info'].copy()

# %%
entriesToRemove = ["teams", "participants"]

for entry in entriesToRemove:
    del dictInfos[entry]
    
dictInfos
# Out:
# {'gameCreation': 1659541674507,
#  'gameDuration': 2560,
#  'gameEndTimestamp': 1659544429539,
#  'gameId': 5999047056,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-5999047056',
#  'gameStartTimestamp': 1659541868788,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '12.14.456.5556',
#  'mapId': 11,
#  'platformId': 'EUW1',
#  'queueId': 420,
#  'tournamentCode': ''}

# %%
dfInfos = pd.DataFrame([dictInfos])
dfInfos
# Out:
#     gameCreation  gameDuration  gameEndTimestamp      gameId gameMode  \
# 0  1659541674507          2560     1659544429539  5999047056  CLASSIC
#
#                        gameName  gameStartTimestamp      gameType  \
# 0  teambuilder-match-5999047056       1659541868788  MATCHED_GAME
#
#       gameVersion  mapId platformId  queueId tournamentCode
# 0  12.14.456.5556     11       EUW1      420

# %% [markdown]
# ### Participants Table
# #### List of champion's bans

# %%
bansList = [element['championId'] for bans in matchDetails['info']['teams'] for element in bans['bans']]
bansList
# Out:
# [84, 39, 107, 555, 25, 25, 555, -1, 895, 122]

# %% [markdown]
# #### List of champion's runes

# %%
perkList = [element for participantDetails in dictParticipants for element in [element['perk'] for styles in participantDetails['perks']['styles'] for element in styles['selections']]]
perkList
# Out:
# [8005,
#  9111,
#  9104,
#  8014,
#  8143,
#  8138,
#  8005,
#  9111,
#  9105,
#  8299,
#  8234,
#  8232,
#  8008,
#  9111,
#  9104,
#  8299,
#  8444,
#  8242,
#  8008,
#  8009,
#  9103,
#  8014,
#  8233,
#  8236,
#  8112,
#  8126,
#  8138,
#  8105,
#  8226,
#  8237,
#  8021,
#  9111,
#  9104,
#  8299,
#  8473,
#  8451,
#  8112,
#  8126,
#  8138,
#  8106,
#  8313,
#  8347,
#  8008,
#  9111,
#  9104,
#  8299,
#  8473,
#  8453,
#  8369,
#  8304,
#  8345,
#  8347,
#  8233,
#  8236,
#  8214,
#  8226,
#  8210,
#  8237,
#  8473,
#  8453]

# %%
dictPerks = list(grouper(perkList, 6, 'x'))
dictPerks
# Out:
# [(8005, 9111, 9104, 8014, 8143, 8138),
#  (8005, 9111, 9105, 8299, 8234, 8232),
#  (8008, 9111, 9104, 8299, 8444, 8242),
#  (8008, 8009, 9103, 8014, 8233, 8236),
#  (8112, 8126, 8138, 8105, 8226, 8237),
#  (8021, 9111, 9104, 8299, 8473, 8451),
#  (8112, 8126, 8138, 8106, 8313, 8347),
#  (8008, 9111, 9104, 8299, 8473, 8453),
#  (8369, 8304, 8345, 8347, 8233, 8236),
#  (8214, 8226, 8210, 8237, 8473, 8453)]

# %%
participantRunes = {}
for i in range(len(dictPerks[0])):
    participantRunes[f'perk{i}'] = []
    for j in dictPerks:
        participantRunes[f'perk{i}'] += [j[i]]

participantRunes
# Out:
# {'perk0': [8005, 8005, 8008, 8008, 8112, 8021, 8112, 8008, 8369, 8214],
#  'perk1': [9111, 9111, 9111, 8009, 8126, 9111, 8126, 9111, 8304, 8226],
#  'perk2': [9104, 9105, 9104, 9103, 8138, 9104, 8138, 9104, 8345, 8210],
#  'perk3': [8014, 8299, 8299, 8014, 8105, 8299, 8106, 8299, 8347, 8237],
#  'perk4': [8143, 8234, 8444, 8233, 8226, 8473, 8313, 8473, 8233, 8473],
#  'perk5': [8138, 8232, 8242, 8236, 8237, 8451, 8347, 8453, 8236, 8453]}

# %%
dfParticipantRunes = pd.DataFrame(participantRunes)
dfParticipantRunes
# Out:
#    perk0  perk1  perk2  perk3  perk4  perk5
# 0   8005   9111   9104   8014   8143   8138
# 1   8005   9111   9105   8299   8234   8232
# 2   8008   9111   9104   8299   8444   8242
# 3   8008   8009   9103   8014   8233   8236
# 4   8112   8126   8138   8105   8226   8237
# 5   8021   9111   9104   8299   8473   8451
# 6   8112   8126   8138   8106   8313   8347
# 7   8008   9111   9104   8299   8473   8453
# 8   8369   8304   8345   8347   8233   8236
# 9   8214   8226   8210   8237   8473   8453

# %%
dfParticipants = pd.DataFrame(dictParticipants)
dfParticipants.head()
# Out:
#    assists  baronKills  basicPings  bountyLevel  \
# 0        5           0          98            6
# 1       18           2          38            0
# 2        9           0          35            0
# 3       10           0          46            0
# 4       17           0           7            0
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'abilityUses': 211,...            20766
# 1  {'12AssistStreakCount': 0, 'abilityUses': 515,...            22147
# 2  {'12AssistStreakCount': 0, 'abilityUses': 476,...            22945
# 3  {'12AssistStreakCount': 0, 'abilityUses': 252,...            19578
# 4  {'12AssistStreakCount': 1, 'abilityUses': 175,...            15085
#
#    champLevel  championId championName  championTransform  ...  \
# 0          18          17        Teemo                  0  ...
# 1          18         106     Volibear                  0  ...
# 2          18         777         Yone                  0  ...
# 3          18         222         Jinx                  0  ...
# 4          16         267         Nami                  0  ...
#
#    trueDamageTaken  turretKills  turretTakedowns  turretsLost  unrealKills  \
# 0              103            2                3            6            0
# 1             2099            1                3            6            0
# 2             5460            3                3            6            0
# 3              741            2                4            6            0
# 4              485            1                4            6            0
#
#    visionScore  visionWardsBoughtInGame  wardsKilled  wardsPlaced   win
# 0           24                        0            2           13  True
# 1           26                        4            1            6  True
# 2           25                        2            1           12  True
# 3           18                        0            2            9  True
# 4           47                        1            1           28  True
#
# [5 rows x 108 columns]

# %% [markdown]
# #### Concatenation of columns

# %%
dfParticipants['bans'] = bansList

removeColumns = ['challenges', 'perks']
for col in removeColumns:
    del dfParticipants[col]

dfParticipants = pd.concat([dfParticipants, dfParticipantRunes], axis=1, join='outer')

# %%
dfParticipants.head()
# Out:
#    assists  baronKills  basicPings  bountyLevel  champExperience  champLevel  \
# 0        5           0          98            6            20766          18
# 1       18           2          38            0            22147          18
# 2        9           0          35            0            22945          18
# 3       10           0          46            0            19578          18
# 4       17           0           7            0            15085          16
#
#    championId championName  championTransform  consumablesPurchased  ...  \
# 0          17        Teemo                  0                     0  ...
# 1         106     Volibear                  0                     6  ...
# 2         777         Yone                  0                     7  ...
# 3         222         Jinx                  0                     1  ...
# 4         267         Nami                  0                     3  ...
#
#    wardsKilled  wardsPlaced   win  bans  perk0  perk1  perk2  perk3  perk4  \
# 0            2           13  True    84   8005   9111   9104   8014   8143
# 1            1            6  True    39   8005   9111   9105   8299   8234
# 2            1           12  True   107   8008   9111   9104   8299   8444
# 3            2            9  True   555   8008   8009   9103   8014   8233
# 4            1           28  True    25   8112   8126   8138   8105   8226
#
#    perk5
# 0   8138
# 1   8232
# 2   8242
# 3   8236
# 4   8237
#
# [5 rows x 113 columns]

# %% [markdown]
# ## CREATING MYSQL TABLES

# %%
dtypesList = list(set(dfParticipants.dtypes))
dtypesList
# Out:
# [dtype('bool'), dtype('O'), dtype('int64')]

# %%
listColumns = []

for i in list(dfParticipants.dtypes.items()):
    if i[1] == dtypesList[0]: # np.object
        listColumns.append(f"{i[0]} VARCHAR(200),")
        
    elif i[1] == dtypesList[1]: # np.int64
        listColumns.append(f"{i[0]} INT,")
        
    else:
        listColumns.append(f"{i[0]} BOOLEAN,")

# %%
createDb = [
    "DROP DATABASE IF EXISTS lol_stats",
    "CREATE DATABASE lol_stats",
    "USE lol_stats"
]

createTable = [
    "DROP TABLE IF EXISTS match_informations",
    '''CREATE TABLE match_informations(
       gameId BIGINT,
       gameCreation BIGINT,
       gameDuration INT,
       gameEndTimestamp BIGINT,
       gameStartTimestamp BIGINT,
       gameVersion CHAR(20),
       PRIMARY KEY(gameId))''',

    "DROP TABLE IF EXISTS participants",
    '''CREATE TABLE participants(
       id INT NOT NULL AUTO_INCREMENT,
       assists INT,
       baronKills INT,
       basicPings INT,
       bountyLevel INT,
       champExperience INT,
       champLevel INT,
       championId INT,
       championName VARCHAR(200),
       championTransform INT,
       consumablesPurchased INT,
       damageDealtToBuildings INT,
       damageDealtToObjectives INT,
       damageDealtToTurrets INT,
       damageSelfMitigated INT,
       deaths INT,
       detectorWardsPlaced INT,
       doubleKills INT,
       dragonKills INT,
       eligibleForProgression BOOLEAN,
       firstBloodAssist BOOLEAN,
       firstBloodKill BOOLEAN,
       firstTowerAssist BOOLEAN,
       firstTowerKill BOOLEAN,
       gameEndedInEarlySurrender BOOLEAN,
       gameEndedInSurrender BOOLEAN,
       goldEarned INT,
       goldSpent INT,
       individualPosition VARCHAR(200),
       inhibitorKills INT,
       inhibitorTakedowns INT,
       inhibitorsLost INT,
       item0 INT,
       item1 INT,
       item2 INT,
       item3 INT,
       item4 INT,
       item5 INT,
       item6 INT,
       itemsPurchased INT,
       killingSprees INT,
       kills INT,
       lane VARCHAR(200),
       largestCriticalStrike INT,
       largestKillingSpree INT,
       largestMultiKill INT,
       longestTimeSpentLiving INT,
       magicDamageDealt INT,
       magicDamageDealtToChampions INT,
       magicDamageTaken INT,
       neutralMinionsKilled INT,
       nexusKills INT,
       nexusLost INT,
       nexusTakedowns INT,
       objectivesStolen INT,
       objectivesStolenAssists INT,
       participantId INT,
       pentaKills INT,
       physicalDamageDealt INT,
       physicalDamageDealtToChampions INT,
       physicalDamageTaken INT,
       profileIcon INT,
       puuid VARCHAR(200),
       quadraKills INT,
       riotIdName VARCHAR(200),
       riotIdTagline VARCHAR(200),
       role VARCHAR(200),
       sightWardsBoughtInGame INT,
       spell1Casts INT,
       spell2Casts INT,
       spell3Casts INT,
       spell4Casts INT,
       summoner1Casts INT,
       summoner1Id INT,
       summoner2Casts INT,
       summoner2Id INT,
       summonerLevel INT,
       summonerId VARCHAR(200),
       summonerName VARCHAR(200),
       teamEarlySurrendered BOOLEAN,
       teamId INT,
       teamPosition VARCHAR(200),
       timeCCingOthers INT,
       timePlayed INT,
       totalDamageDealt INT,
       totalDamageDealtToChampions INT,
       totalDamageShieldedOnTeammates INT,
       totalDamageTaken INT,
       totalHeal INT,
       totalHealsOnTeammates INT,
       totalMinionsKilled INT,
       totalTimeCCDealt INT,
       totalTimeSpentDead INT,
       totalUnitsHealed INT,
       tripleKills INT,
       trueDamageDealt INT,
       trueDamageDealtToChampions INT,
       trueDamageTaken INT,
       turretKills INT,
       turretTakedowns INT,
       turretsLost INT,
       unrealKills INT,
       visionScore INT,
       visionWardsBoughtInGame INT,
       wardsKilled INT,
       wardsPlaced INT,
       win BOOLEAN,
       bans INT,
       perk0 INT,
       perk1 INT,
       perk2 INT,
       perk3 INT,
       perk4 INT,
       perk5 INT,
       gameId BIGINT,
       PRIMARY KEY(id),
       FOREIGN KEY(gameId) REFERENCES match_informations(gameId))'''
]

# %%
# Connection à l'instance de la database
def connect_to_instance_db():
    try:
        conn = pymysql.connect(
                host='localhost',
                user='root',
                password=ACCESS_DB,
                charset='utf8mb4')
    except pymysql.err.OperationalError as e:
        raise e
    else:
        print("Connection Successful!")
    return conn

def request_query(queries):
    connection = connect_to_instance_db()
    cursor = connection.cursor()
        
    for query in queries:
        cursor.execute(query)
        connection.commit()
        
    print("Queries have been successfully completed")

# %%
request_query(createDb + createTable)
# Out:
# Connection Successful!
# Queries have been successfully completed
